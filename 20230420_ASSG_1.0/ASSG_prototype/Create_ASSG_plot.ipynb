# %%
#################################################################################################################
#################################################  1D-ASSG   ####################################################
#################################################################################################################

# %run ../Packages/2D_ASSG_definations.ipynb #imports packages
# %run ../Packages/1D_ASSG_definations.ipynb #imports packages

#insert datapath as follows:
# plot_1D_ASSG("path_to_indicator", "path_to_fig_including_name.jpg", "title", "name of indicator")
# data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....
plot_1D_ASSG("../data/examples/example_data_indicator_1.txt",
            "1D_ASSG_example.jpg",
            "ASSG example",
            "indicator 1")

# %%
#################################################################################################################
#################################################  2D-ASSG   ####################################################
#################################################################################################################

# %run ../packages/2D_ASSG_definations.ipynb #imports packages
#insert datapath as follows:
# plot_2D_ASSG("path_to_indicator1","path_to_indcator2", "path_to_fig_including_name.jpg", "title", "name of indicator 1", "name of indicator 2")
# data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....
plot_2D_ASSG_with_slicing(0, -1,"../data/examples/example_data_indicator_1.txt",
             "../data/examples/example_data_indicator_2.txt",
            "2D_ASSG_example.jpg",
            "ASSG example",
            "indicator 1",
            "indicator 2")

# %%
#################################################################################################################
##########################################  2D-ASSG with disruption  ############################################
#################################################################################################################

# %run ../packages/2D_ASSG_definations.ipynb #imports packages
#insert datapath as follows:
# plot_2D_ASSG(old_attraktor_last_time_slot, new_stability_first_time_slot,"path_to_indicator1","path_to_indcator2", "path_to_fig_including_name.jpg", "title", "name of indicator 1", "name of indicator 2")
# data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....
plot_2D_ASSG_with_disruption(0, 21,26, -1,"../data/examples/disruption_example_indicator_1.txt",
             "../data/examples/disruption_example_indicator_2.txt",
            "2D_ASSG_example_with_disruption.jpg",
            "ASSG with disruption",
            "indicator 1",
            "indicator 2")
# Out:
# C:\Users\Niklas\anaconda3\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
#################################################################################################################
##########################################  2D-ASSG with disruption  ############################################
#################################################################################################################

# %run ../packages/2D_ASSG_definations.ipynb #imports packages
#insert datapath as follows:
# plot_2D_ASSG(old_attraktor_last_time_slot, new_stability_first_time_slot,"path_to_indicator1","path_to_indcator2", "path_to_fig_including_name.jpg", "title", "name of indicator 1", "name of indicator 2")
# data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....
plot_2D_ASSG_with_disruption(5, 18, 23, -4,
            "../data/play_game/lesson_1_free_fall/lesson_1_free_fall_teacher_agency.txt",
             "../data/play_game/lesson_1_free_fall/lesson_1_free_fall_views_to_class_action.txt",
            "2D_ASSG_example_with_disruption_and_real_data.jpg",
            "Play game",
            "teacher agency",
            "views to class action")

# %%
plot_2D_ASSG(
            "../data/play_game/lesson_1_free_fall/lesson_1_free_fall_teacher_agency.txt",
             "../data/play_game/lesson_1_free_fall/lesson_1_free_fall_views_to_class_action.txt",
            "2D_ASSG_example_with_disruption_and_real_data.jpg",
            "Play game",
            "teacher agency",
            "views to class action")
