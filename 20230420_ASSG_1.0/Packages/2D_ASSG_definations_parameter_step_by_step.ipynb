# %%
##################################################################
################### last update 20230228 #########################
##################################################################
def plot_2D_ASSG_1_SSG(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='skyblue', zorder=3)
    (ax.set_xlabel('%s'
                   %(name_indicator_1), fontsize='22'))
    (ax.set_ylabel('%s'
                   %(name_indicator_2), fontsize='22'))
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='skyblue', zorder=-5)[0]
    plt.plot(x_reloc, y_reloc, color='skyblue')
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
#title
    ax.set_title(title, fontsize='21')
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_2_color_points(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s'
                   %(name_indicator_1), fontsize='22'))
    (ax.set_ylabel('%s'
                   %(name_indicator_2), fontsize='22'))
#title
    ax.set_title(title, fontsize='21')
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_3_EV(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s'
                   %(name_indicator_1), fontsize='22'))
    (ax.set_ylabel('%s'
                   %(name_indicator_2), fontsize='22'))
#title
    ax.set_title(title, fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_4_MSD(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1]) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))

#title
    ax.set_title('%s, MSD=%.2f'
                                 %(title, round(MSD, 2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_5_deviation_curve(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1]) 
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))

#title
    ax.set_title('%s, MSD=%.2f'
                                 %(title, round(MSD, 2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_6_SDD(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_7_const_fits(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst_no_errors(x,y)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst_no_errors(x,y)), zorder=20)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_8_linear_fit(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst_no_errors(x,y)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst_no_errors(x,y)), zorder=20)
#plot of linear fits
    ax.plot(xfit,yfit,linewidth='3',color='fuchsia',
                                label='m =%.2f, $\chi_{lin}^2$=%.2f'
                            %(popt[0], chi_linear_no_errors(x,y)), zorder=25)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_9_error_bars_no_fits(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_10_error_bars_constant_fits(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#fitting
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_11_error_bars_linear_fit(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue', zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#plot of linear fits
    ax.plot(xfit,yfit,linewidth='3',color='fuchsia',
                                label='m =%.2f, $\chi_{lin}^2$=%.2f'
                            %(popt[0], chi_linear(x,y, x_err, y_err)), zorder=25)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s'
                   %(name_indicator_1, round(dm[0], 2)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s'
                   %(name_indicator_2, round(dm[1], 2)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_12_td(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue',label='td=%.2f' 
                                        %(traveldistance(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#plot of linear fits
    ax.plot(xfit,yfit,linewidth='3',color='fuchsia',
                                label='m =%.2f, $\chi_{lin}^2$=%.2f'
                            %(popt[0], chi_linear(x,y, x_err, y_err)), zorder=25)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_13_ipd(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#MSD
    MSD = 0.5*(dm[0]+dm[1])
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    ipd=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1) 
    scatter_label= ax.scatter(x_reloc,y_reloc,s=time(x,y), c='cornflowerblue', zorder=3)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue',label='td=%.2f' 
                                        %(traveldistance(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse, ipd=%.2f'%(round(ipd, 2)), zorder=30)
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#plot of linear fits
    ax.plot(xfit,yfit,linewidth='3',color='fuchsia',
                                label='m =%.2f, $\chi_{lin}^2$=%.2f'
                            %(popt[0], chi_linear(x,y, x_err, y_err)), zorder=25)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_14_tt(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, skiprows=1,  unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, skiprows=1, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    x_reloc, y_reloc = relocating(x,y)
    size=time(x,y)
###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#angle for deviationscurve
    phi = np.linspace(0,2*np.pi,100)
#defination of deviationcurve
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#MSD
    MSD = 0.5*(dm[0]+dm[1]) 
#SDD
    SDD = np.absolute(dm[0]-dm[1])
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    ipd=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1)
#points of ASSG-plot
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=time(x,y)[0], c='cornflowerblue',label='td=%.2f, tt=%.2f' 
                                        %(traveldistance(x,y),traveltendency(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=time(x,y), c=df.z, cmap='Blues', zorder=4)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of EV
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s, %s$)^T$'
                               %(round(m[0], 2), round(m[1], 2)), zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse, ipd=%.2f'%(round(ipd, 2)), zorder=30)

#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#plot of linear fits
    ax.plot(xfit,yfit,linewidth='3',color='fuchsia',
                                label='m =%.2f, $\chi_{lin}^2$=%.2f'
                            %(popt[0], chi_linear(x,y, x_err, y_err)), zorder=25)
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#labels
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f, $tt_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x), 2*traveltendency(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f, $tt_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y),2*traveltendency(y,y)), fontsize='22'))
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_paper_1_1_single_parameters(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    size=time(x,y)
    x_reloc, y_reloc = relocating(x,y)

###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#middle SD
    MSD = 0.5*(dm[0]+dm[1]) 
#SD difference
    SDD = np.absolute(dm[0]-dm[1])
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    dens=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1)
#points of ASSG-plot
    
    
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], c='cornflowerblue',label='td=%.2f, tt=%.2f' 
                                        %(traveldistance(x,y),traveltendency(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=size, c=df.z, cmap='Blues', zorder=4)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
    
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
    
    
    
    
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f, $tt_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x), 2*traveltendency(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f, $tt_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y),2*traveltendency(y,y)), fontsize='22'))
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of meanvalue
    ev_list_x=np.zeros(len(x_data))
    ev_list_y=np.zeros(len(y_data))
    for j in range(len(x_data)): #slope of rater
        ev_list_x[j]+= meanlist(x_data[j])
        ev_list_y[j]+= meanlist(y_data[j])
    const_for_ev_x=np.full(shape=50, fill_value=m[1])
    const_for_ev_y=np.full(shape=50, fill_value=m[0])
    #point of ev
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s$\pm$%s, %s$\pm$%s$)^T$'
                               %(round(m[0], 2), round(stdlist(ev_list_x)/np.sqrt(len(x_data)), 2),
                                 round(m[1], 2), round(stdlist(ev_list_y)/np.sqrt(len(y_data)), 2)),
               zorder=35)
    #errorbar
    #ev x error
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x, 
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x,
            color='crimson', linewidth=7, zorder=35)
    #ev y error
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='crimson', linewidth=7, zorder=35)
#plot of deviation ellipse
    #ax.plot(cx,cy, ls='-.',color='crimson',
    #                        label='deviation ellipse, ipd=%.2f'%(round(dens, 2)), zorder=30)
#title
    ax.set_title('%s'
                                 %(title), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_paper_1_2_msd_sdd_de(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    size=time(x,y)
    x_reloc, y_reloc = relocating(x,y)

###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#middle SD
    MSD = 0.5*(dm[0]+dm[1]) 
#SD difference
    SDD = np.absolute(dm[0]-dm[1])
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    dens=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1)
#points of ASSG-plot
    
    
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], c='cornflowerblue',label='td=%.2f, tt=%.2f' 
                                        %(traveldistance(x,y),traveltendency(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=size, c=df.z, cmap='Blues', zorder=4)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
    
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
    
    
    
    
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f, $tt_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x), 2*traveltendency(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f, $tt_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y),2*traveltendency(y,y)), fontsize='22'))
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of meanvalue
    ev_list_x=np.zeros(len(x_data))
    ev_list_y=np.zeros(len(y_data))
    for j in range(len(x_data)): #slope of rater
        ev_list_x[j]+= meanlist(x_data[j])
        ev_list_y[j]+= meanlist(y_data[j])
    const_for_ev_x=np.full(shape=50, fill_value=m[1])
    const_for_ev_y=np.full(shape=50, fill_value=m[0])
    #point of ev
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s$\pm$%s, %s$\pm$%s$)^T$'
                               %(round(m[0], 2), round(stdlist(ev_list_x)/np.sqrt(len(x_data)), 2),
                                 round(m[1], 2), round(stdlist(ev_list_y)/np.sqrt(len(y_data)), 2)),
               zorder=35)
    #errorbar
    #ev x error
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x, 
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x,
            color='crimson', linewidth=7, zorder=35)
    #ev y error
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='crimson', linewidth=7, zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse', zorder=30)
    #ax.plot(cx,cy, ls='-.',color='crimson',
    #                        label='deviation ellipse, ipd=%.2f'%(round(dens, 2)), zorder=30)
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_paper_1_3_ipd(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    size=time(x,y)
    x_reloc, y_reloc = relocating(x,y)

###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#middle SD
    MSD = 0.5*(dm[0]+dm[1]) 
#SD difference
    SDD = np.absolute(dm[0]-dm[1])
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    dens=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1)
#points of ASSG-plot
    
    
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], c='cornflowerblue',label='td=%.2f, tt=%.2f' 
                                        %(traveldistance(x,y),traveltendency(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=size, c=df.z, cmap='Blues', zorder=4)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
    
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
    
    
    
    
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f, $tt_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x), 2*traveltendency(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f, $tt_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y),2*traveltendency(y,y)), fontsize='22'))
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=40)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=45)
#plot of meanvalue
    ev_list_x=np.zeros(len(x_data))
    ev_list_y=np.zeros(len(y_data))
    for j in range(len(x_data)): #slope of rater
        ev_list_x[j]+= meanlist(x_data[j])
        ev_list_y[j]+= meanlist(y_data[j])
    const_for_ev_x=np.full(shape=50, fill_value=m[1])
    const_for_ev_y=np.full(shape=50, fill_value=m[0])
    #point of ev
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s$\pm$%s, %s$\pm$%s$)^T$'
                               %(round(m[0], 2), round(stdlist(ev_list_x)/np.sqrt(len(x_data)), 2),
                                 round(m[1], 2), round(stdlist(ev_list_y)/np.sqrt(len(y_data)), 2)),
               zorder=35)
    #errorbar
    #ev x error
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x, 
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x,
            color='crimson', linewidth=7, zorder=35)
    #ev y error
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='crimson', linewidth=7, zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse, ipd=%.2f'%(round(dens, 2)), zorder=30)
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#legend
    ax.legend(ncol=2, fontsize='18').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()

# %%
def plot_2D_ASSG_paper_1_4_stationary(path_data1, path_data2, path_fig, title, name_indicator_1, name_indicator_2):
    x_data_not_arranged=np.loadtxt(path_data1, unpack=True)
    x_data=np.array(x_data_not_arranged).T
    y_data_not_arranged=np.loadtxt(path_data2, unpack=True)
    y_data=np.array(y_data_not_arranged).T
    all_ratings_x=np.zeros(len(x_data_not_arranged[0])*len(x_data[1]))
    for j in range(len(x_data_not_arranged[0])):#slope of rater
        for k in range(len(x_data[0])):
            position_rating_x=k+j*len(x_data[j])
            all_ratings_x[position_rating_x]=+(x_data[j][k])
    all_ratings_y=np.zeros(len(y_data_not_arranged[1])*len(y_data[1]))
    for j in range(len(y_data_not_arranged[1])):#slope of rater
        for k in range(len(y_data[1])):
            position_rating_y=k+j*len(y_data[j])
            all_ratings_y[position_rating_y]=+(y_data[j][k])
    x, x_err = ratings_mean_and_error(all_ratings_x, len(x_data_not_arranged[1]), len(x_data[1]))
    y, y_err = ratings_mean_and_error(all_ratings_y, len(y_data_not_arranged[1]), len(y_data[1]))
    size=time(x,y)
    x_reloc, y_reloc = relocating(x,y)

###--------------------definations for the values---------------------------
#shorting of names for meanvalue and deviation
    m = [meanlist(x), meanlist(y)]
    dm = std(x,y)
#angle for deviation ellipse
    phi = np.linspace(0,2*np.pi,100)
#defination of deviation ellipse
    cx = m[0]+dm[0]*np.cos(phi)
    cy = m[1]+dm[1]*np.sin(phi)
#middle SD
    MSD = 0.5*(dm[0]+dm[1]) 
#SD difference
    SDD = np.absolute(dm[0]-dm[1])
#fitting
#linear
    popt, pcov = curve_fit(lin,x,y, bounds=([-5,-25], [5, 25]))
    xfit=np.linspace(0, 6)
    yfit=popt[0]*xfit+popt[1]
#xconst
    poptx, pcovx = curve_fit(xconst,x,y)
    xfit_xconst=np.linspace(0, 6)
    yfit_xconst=poptx[0]+0*xfit_xconst
#yconst
    popty, pcovy = curve_fit(xconst,y,x)
    yfit_yconst=np.linspace(0, 6)
    xfit_yconst=popty[0]+0*yfit_yconst
#inner point density
    dens=density(x,y) 
###---------------------------Plots-----------------------------------------
#size
    fig, ax = plt.subplots(figsize=(12,12))
#add grid
    grid_chessboard(5+1,5+1)
#points of ASSG-plot
    
    
    df = pd.DataFrame({'z': (np.linspace(0, len(x), len(x)))})
    scatter_label= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], c='cornflowerblue',label='td=%.2f, tt=%.2f' 
                                        %(traveldistance(x,y),traveltendency(x,y)), zorder=3)
    scatter= ax.scatter(x_reloc,y_reloc,s=size, c=df.z, cmap='Blues', zorder=4)
#color errorbars
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor='whitesmoke', elinewidth=3, zorder=10)
    errorbar_color = (np.linspace(0, len(x), len(x)))
    cmap = cm.Blues
    norm = Normalize(vmin=errorbar_color.min(), vmax=errorbar_color.max())
    plt.errorbar(x_reloc, y_reloc, y_err, x_err, fmt='none', ecolor=cmap(norm(errorbar_color)), elinewidth=7, zorder=8)
    plt.errorbar(x_reloc[-1], y_reloc[-1], y_err[-1], x_err[-1], fmt='none',
                 ecolor=cmap(norm(errorbar_color))[-1],
                 label='$\overline{\Delta x}$=%.2f $\pm$ %.2f, \n$\overline{\Delta y}$=%.2f $\pm$ %.2f'
                 %(meanlist(x_err), stdlist(x_err), meanlist(y_err), stdlist(y_err)), zorder=1)
    
    points=np.array([x_reloc, y_reloc]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    lc = mc.LineCollection(segments, cmap='Blues', norm=norm)
    ax.add_collection(lc)
    lc.set_array(np.linspace(10, len(x), len(x)))
    
    
    
    
    (ax.set_xlabel('%s, $SD_x$=%s, $td_x$=%.2f, $tt_x$=%.2f'
                   %(name_indicator_1, round(dm[0], 2), 2**(-0.5)*traveldistance(x,x), 2*traveltendency(x,x)), fontsize='22'))
    (ax.set_ylabel('%s, $SD_y$=%s, $td_y$=%.2f, $tt_y$=%.2f'
                   %(name_indicator_2, round(dm[1], 2), 2**(-0.5)*traveldistance(y,y),2*traveltendency(y,y)), fontsize='22'))
###------------------------------------------Cosmetics----------------------------------------------------------
#limit of Axes
    ax.set_xlim([0.5,5+0.5])
    ax.set_ylim([0.5,5+0.5])
#add arrows
    line=plt.plot(x_reloc, y_reloc, markersize=0, color='cornflowerblue', zorder=-5)[0]
    add_arrow(ax, line, arrow_locs=np.linspace(0, 1, 30),arrowstyle='->', arrowsize=4)
#start and end value
    start= ax.scatter(x_reloc[0],y_reloc[0],s=size[0], color='limegreen', zorder=45)
    end= ax.scatter(x_reloc[-1],y_reloc[-1],s=(size[-1]/10),color='gold', zorder=50)
#plot of meanvalue
    ev_list_x=np.zeros(len(x_data))
    ev_list_y=np.zeros(len(y_data))
    for j in range(len(x_data)): #slope of rater
        ev_list_x[j]+= meanlist(x_data[j])
        ev_list_y[j]+= meanlist(y_data[j])
    const_for_ev_x=np.full(shape=50, fill_value=m[1])
    const_for_ev_y=np.full(shape=50, fill_value=m[0])
    #point of ev
    ax.scatter([m[0]],[m[1]],s=300, color='crimson',
                                label='EV: (%s$\pm$%s, %s$\pm$%s$)^T$'
                               %(round(m[0], 2), round(stdlist(ev_list_x)/np.sqrt(len(x_data)), 2),
                                 round(m[1], 2), round(stdlist(ev_list_y)/np.sqrt(len(y_data)), 2)),
               zorder=35)
    #errorbar
    #ev x error
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x, 
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(np.linspace(m[0]-stdlist(ev_list_x)/np.sqrt(len(x_data)),
                    m[0]+stdlist(ev_list_x)/np.sqrt(len(x_data)), 50),
            const_for_ev_x,
            color='crimson', linewidth=7, zorder=35)
    #ev y error
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='whitesmoke', linewidth=3, zorder=40)
    ax.plot(const_for_ev_y,
            np.linspace(m[1]-stdlist(ev_list_y)/np.sqrt(len(y_data)),
                    m[1]+stdlist(ev_list_y)/np.sqrt(len(y_data)), 50),
            color='crimson', linewidth=7, zorder=35)
#plot of deviation ellipse
    ax.plot(cx,cy, ls='-.',color='crimson',
                            label='deviation ellipse, ipd=%.2f'%(round(dens, 2)), zorder=30)
#title
    ax.set_title('%s, MSD=%.2f, SDD=%.2f'
                                 %(title, round(MSD, 2), round(SDD,2)), fontsize='21')
#plot of constant fits
    ax.plot(xfit_xconst,yfit_xconst, ls='-.', color='black', 
                                label='y =%.2f, $\chi_{y}^2$=%.2f'
                            %(poptx[0], chi_xconst(x,y, x_err, y_err)), zorder=20)
    ax.plot(xfit_yconst,yfit_yconst, ls='-.', color='black', 
                                label='x =%.2f, $\chi_{x}^2$=%.2f'
                            %(popty[0], chi_yconst(x,y, x_err, y_err)), zorder=20)
#legend
    ax.legend(ncol=2, fontsize='19').set_zorder(100)
###--------------------------------------------Saving---------------------------------------------------------
    plt.savefig(path_fig, bbox_inches='tight')
    plt.show()
