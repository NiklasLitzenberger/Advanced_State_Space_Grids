# %%
#################################################################################################################
#################################################  1D-ASSG   ####################################################
#################################################################################################################

# First import packages
# %run ../Packages/2D_ASSG_definations.ipynb #(This has the basic functions you need for 1D-ASSGs too)
# %run ../Packages/1D_ASSG_definations.ipynb


# Insert datapath into the short code as follows:
# plot_1D_ASSG(
# "path_to_indicator_ratings",
# "path_to_fig_including_name.jpg",
# "title",
# "name of indicator"
# )


# Data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....


# Note that this code only works if you insert more than one rater.
# Additionally these ratings need to include at least one rating which is not the same in all raters

#Here is an example:
plot_1D_ASSG("../data/examples/example_data_indicator_1.txt",
            "1D_ASSG_example.jpg",
            "ASSG example",
            "example")

# %%
#################################################################################################################
#################################################  2D-ASSG   ####################################################
#################################################################################################################

# First import packages
# %run ../packages/2D_ASSG_definations.ipynb 

# Insert datapath into the short code as follows:
# plot_2D_ASSG(
# "path_to_indicator1",
# "path_to_indcator2",
# "path_to_fig_including_name.jpg",
# "title",
# "name of indicator 1",
# "name of indicator 2"
# )


# Data has to be in this format:
# rating_rater_1_timesample_1, rating_rater_1_timesample_2, rating_rater_1_timesample_3,....
# rating_rater_2_timesample_1, rating_rater_2_timesample_2, rating_rater_2_timesample_3,....
# rating_rater_3_timesample_1, rating_rater_3_timesample_2, rating_rater_3_timesample_3,....


# Note that this code only works if you insert more than one rater.
# Additionally these ratings need to include at least one rating which is not the same in all raters

#Here is an example:
plot_2D_ASSG(
            "../data/examples/example_data_indicator_1.txt",
             "../data/examples/example_data_indicator_2.txt",
            "2D_ASSG_example.jpg",
            "ASSG example",
            "indicator 1",
            "indicator 2")
